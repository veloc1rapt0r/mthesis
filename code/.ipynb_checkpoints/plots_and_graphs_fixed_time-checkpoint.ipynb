# %% [markdown]
# # Plots

# %%
import sys
sys.path.append("../")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch, torch.nn as nn
import torchvision, torchvision.transforms as tt
import os
from os.path import exists
import seaborn as sns
import matplotlib.ticker as mticker

# %% [markdown]
# # utils

# %%
# Creates a pandas dataframe if file exist
# Input:    String -  Path to the .csv log file
# Output:   pandas.DataFrame
def create_df_if_exist(path):
    if exists(path):
        return pd.read_csv(path, sep=',')
    else:
        print('No file exist', path)
        return None

# Creates 4 dataframes, with validate, train, and runtime logs.
# Input:    String -  Path to the .csv log file
# Output:   Tuple of 4 pandas.DataFrame's
def create_dfs_filename(path):
    path_val = path + '_val.csv'
    path_train =  path + '_train.csv'
    path_test = path + '_test.csv'
    path_runtime = path + '_runtime.csv'
    return create_df_if_exist(path_val), create_df_if_exist(path_train), create_df_if_exist(path_test), create_df_if_exist(path_runtime)

# %%
logs_folder = '/home/coder/Course_Materials/logs/'

if not os.path.isdir(logs_folder):
    #logs_folder = '/Users/olehbakumenko/PycharmProjects/Git/Course_Materials/logs/'
    logs_folder = '/Users/olehbakumenko/PycharmProjects/MasterThesis/logs/'

# %%
logs_folder
# Out:
# '/Users/olehbakumenko/PycharmProjects/MasterThesis/logs/'

# %%
def plot_confusion_matrix(path, print_per_class_acc = True, print_mean = False, title_above = None):
    if exists(path):
            conf_matr = torch.load(path)
    else:
        print('No file exist', path)
        return None
    per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
    mean = torch.mean(per_class_accuracy)
    per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
    mean_np = np.array2string(np.round(mean.detach().numpy(),2))
    class_names = ['0', '  1', ' 2']
    df_cm = pd.DataFrame(conf_matr, class_names, class_names)
    plt.figure()
    sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
    plt.xlabel("Prediction")
    plt.ylabel("Target")
    if print_per_class_acc:
        title = f"Per class  accuracy:  { per_class_accuracy_np}"
        if print_mean:
            title = title + ", Mean: ["+mean_np+"]"
        plt.title(title,y = -0.2)
    if (title_above is not None):
        plt.title(title_above, y = 1.05)
    plt.show()

# %%
color_AlexNet = 'blue'
color_ResNet18 = 'green'
color_ResNet34 = 'purple'
color_ResNet50 = 'orange'
color_ResNet152 = 'pink'
color_VGG19 = 'firebrick'

color_ResNet34_plain = 'gray'
color_ResNet18_init = 'lime'
color_ResNet34_init = 'fuchsia'
color_ResNet50_init = 'moccasin'
color_ResNet152_init = 'peru'

colors = ['blue', 'orange', 'limegreen', 'red']

# %% [markdown]
# # Create dataframes for the logs
# pandas.DataFrame is a convenient way to save, analyze and visualize the logs data

# %%
filename = 'AlexNet'
df_AlexNet_val, df_AlexNet_train, df_AlexNet_test, df_AlexNet_runtime = create_dfs_filename(logs_folder+filename)

# %%
filename = 'ResNet18'
df_ResNet18_val, df_ResNet18_train, df_ResNet18_test, df_ResNet18_runtime = create_dfs_filename(logs_folder+filename)

# %%
filename = 'ResNet34'
df_ResNet34_val, df_ResNet34_train, df_ResNet34_test, df_ResNet34_runtime = create_dfs_filename(logs_folder+filename)

# %%
filename = 'ResNet34_init'
df_ResNet34_init_val, df_ResNet34_init_train, df_ResNet34_init_test, df_ResNet34_init_runtime = create_dfs_filename(logs_folder+filename)

# %%
filename = 'ResNet50'
df_ResNet50_val, df_ResNet50_train, df_ResNet50_test, df_ResNet50_runtime = create_dfs_filename(logs_folder+filename)

# %%
filename = 'ResNet50_init'
df_ResNet50_init_val, df_ResNet50_init_train, df_ResNet50_init_test, df_ResNet50_init_runtime = create_dfs_filename(logs_folder+filename)

# %%
filename = 'ResNet152_rand'
df_ResNet152_val, df_ResNet152_train, df_ResNet152_test, df_ResNet152_runtime = create_dfs_filename(logs_folder+filename)
# The runtime log for ResNet152_rand was lost after training. It was decided not to rerun it because of the model's poor performance,
# which we determined was not worth the effort.
# Out:
# No file exist /Users/olehbakumenko/PycharmProjects/MasterThesis/logs/ResNet152_rand_runtime.csv

# %%
filename = 'ResNet152_init'
df_ResNet152_init_val, df_ResNet152_init_train, df_ResNet152_init_test, df_ResNet152_init_runtime = create_dfs_filename(logs_folder+filename)

# %%
filename = 'VGG19'
df_VGG19_val, df_VGG19_train, df_VGG19_test, df_VGG19_runtime = create_dfs_filename(logs_folder+filename)

# %%
val_accuracy = pd.DataFrame()
val_accuracy['AlexNet'] = df_AlexNet_val['val_accuracy']
val_accuracy['ResNet18'] = df_ResNet18_val['val_accuracy']
val_accuracy['ResNet34'] = df_ResNet34_val['val_accuracy']
val_accuracy['ResNet34_init'] = df_ResNet34_init_val['val_accuracy']
val_accuracy['ResNet50'] = df_ResNet50_val['val_accuracy']
val_accuracy['ResNet50_init'] = df_ResNet50_init_val['val_accuracy']
val_accuracy['ResNet152'] = df_ResNet152_val['val_accuracy']
val_accuracy['ResNet152_init'] = df_ResNet152_init_val['val_accuracy']
val_accuracy['VGG19'] = df_VGG19_val['val_accuracy']
val_accuracy = val_accuracy.mul(100)

# %%
val_loss = pd.DataFrame()
val_loss['AlexNet'] = df_AlexNet_val['val_loss']
val_loss['ResNet18'] = df_ResNet18_val['val_loss']
val_loss['ResNet34'] = df_ResNet34_val['val_loss']
val_loss['ResNet34_init'] = df_ResNet34_init_val['val_loss']
val_loss['ResNet50'] = df_ResNet50_val['val_loss']
val_loss['ResNet50_init'] = df_ResNet50_init_val['val_loss']
val_loss['ResNet152'] = df_ResNet152_val['val_loss']
val_loss['ResNet152_init'] = df_ResNet152_init_val['val_loss']
val_loss['VGG19'] = df_VGG19_val['val_loss']

# %%
test_accuracy = pd.DataFrame()
test_accuracy['AlexNet'] = df_AlexNet_test['test_accuracy']
test_accuracy['ResNet18'] = df_ResNet18_test['test_accuracy']
test_accuracy['ResNet34'] = df_ResNet34_test['test_accuracy']
test_accuracy['ResNet34_init'] = df_ResNet34_init_test['test_accuracy']
test_accuracy['ResNet50'] = df_ResNet50_test['test_accuracy']
test_accuracy['ResNet50_init'] = df_ResNet50_init_test['test_accuracy']
test_accuracy['ResNet152'] = df_ResNet152_test['test_accuracy']
test_accuracy['ResNet152_init'] = df_ResNet152_init_test['test_accuracy']
test_accuracy['VGG19'] = df_VGG19_test['test_accuracy']
test_accuracy = test_accuracy.mul(100)

# %%
test_loss = pd.DataFrame()
test_loss['AlexNet'] = df_AlexNet_test['test_loss']
test_loss['ResNet18'] = df_ResNet18_test['test_loss']
test_loss['ResNet34'] = df_ResNet34_test['test_loss']
test_loss['ResNet34_init'] = df_ResNet34_init_test['test_loss']
test_loss['ResNet50'] = df_ResNet50_test['test_loss']
test_loss['ResNet50_init'] = df_ResNet50_init_test['test_loss']
test_loss['ResNet152'] = df_ResNet152_test['test_loss']
test_loss['ResNet152_init'] = df_ResNet152_init_test['test_loss']
test_loss['VGG19'] = df_VGG19_test['test_loss']

# %%
runtime = pd.DataFrame()
runtime['AlexNet'] = df_AlexNet_runtime['runtime']
runtime['ResNet18'] = df_ResNet18_runtime['runtime']
runtime['ResNet34'] = df_ResNet34_runtime['runtime']
runtime['ResNet34_init'] = df_ResNet34_init_runtime['runtime']
runtime['ResNet50'] = df_ResNet50_runtime['runtime']
runtime['ResNet50_init'] = df_ResNet50_init_runtime['runtime']
runtime['ResNet152_init'] = df_ResNet152_init_runtime['runtime']
runtime['VGG19'] = df_VGG19_runtime['runtime']

# %%
train_loss_AlexNet = df_AlexNet_train['loss'].to_numpy()
train_loss_ResNet18 = df_ResNet18_train['loss'].to_numpy()
train_loss_ResNet34 = df_ResNet34_train['loss'].to_numpy()
train_loss_ResNet34_init = df_ResNet34_init_train['loss'].to_numpy()
train_loss_ResNet50 = df_ResNet50_train['loss'].to_numpy()
train_loss_ResNet50_init = df_ResNet50_init_train['loss'].to_numpy()
train_loss_ResNet152_init = df_ResNet152_init_train['loss'].to_numpy()
train_loss_VGG = df_VGG19_train['loss'].to_numpy()

# %%
train_loss_AlexNet_tensor = np.array(train_loss_AlexNet)
train_loss_AlexNet_tensor = torch.tensor(train_loss_AlexNet_tensor).view(15, -1)
mean_train_loss_AlexNet = train_loss_AlexNet_tensor.mean(1, True)

train_loss_ResNet18_tensor = np.array(train_loss_ResNet18)
train_loss_ResNet18_tensor = torch.tensor(train_loss_ResNet18_tensor).view(15, -1)
mean_train_loss_ResNet18 = train_loss_ResNet18_tensor.mean(1, True)

train_loss_ResNet34_tensor = np.array(train_loss_ResNet34)
train_loss_ResNet34_tensor = torch.tensor(train_loss_ResNet34_tensor).view(15, -1)
mean_train_loss_ResNet34 = train_loss_ResNet34_tensor.mean(1, True)

train_loss_ResNet50_tensor = np.array(train_loss_ResNet50)
train_loss_ResNet50_tensor = torch.tensor(train_loss_ResNet50_tensor).view(15, -1)
mean_train_loss_ResNet50 = train_loss_ResNet50_tensor.mean(1, True)

train_loss_VGG_tensor = np.array(train_loss_VGG)
train_loss_VGG_tensor = torch.tensor(train_loss_VGG_tensor).view(15, -1)
mean_train_loss_VGG19 = train_loss_VGG_tensor.mean(1, True)

# %% [markdown]
# ------

# %%
# Creates a pandas dataframe if file exist
# Input:    String -  Path to the .csv log file
# Output:   pandas.DataFrame
def create_df_if_exist(path):
    if exists(path):
        return pd.read_csv(path, sep=',')
    else:
        print('No file exist', path)
        return None

# Creates 4 dataframes, with validate, train, and runtime logs.
# Input:    String -  Path to the .csv log file
# Output:   Tuple of 4 pandas.DataFrame's
def create_dfs_fixed_time(path):
    return create_df_if_exist( path + '_val.csv'), create_df_if_exist(path + '_test.csv')

# %%
df_AlexNet_fixed_time_lre3_val,df_AlexNet_fixed_time_lre3_test = create_dfs_fixed_time(logs_folder+"fixed_time_rerun_1004/AlexNet/AlexNet_fixed_time_rerun_1004_lre3")
df_AlexNet_fixed_time_lre4_val,df_AlexNet_fixed_time_lre4_test = create_dfs_fixed_time(logs_folder+"fixed_time_rerun_1004/AlexNet/AlexNet_fixed_time_rerun_1004_lre4")
df_AlexNet_fixed_time_lre5_val,df_AlexNet_fixed_time_lre5_test = create_dfs_fixed_time(logs_folder+"fixed_time_rerun_1004/AlexNet/AlexNet_fixed_time_rerun_1004_lre5")


df_ResNet18_fixed_time_lre3_val,df_ResNet18_fixed_time_lre3_test = create_dfs_fixed_time(logs_folder+"fixed_time_rerun_1004/18/ResNet18_fixed_time_rerun_1004_lre3")
df_ResNet18_fixed_time_lre4_val,df_ResNet18_fixed_time_lre4_test = create_dfs_fixed_time(logs_folder+"fixed_time_rerun_1004/18/ResNet18_fixed_time_rerun_1004_lre4")
df_ResNet18_fixed_time_lre5_val,df_ResNet18_fixed_time_lre5_test = create_dfs_fixed_time(logs_folder+"fixed_time_rerun_1004/18/ResNet18_fixed_time_rerun_1004_lre5")


df_ResNet34_fixed_time_lre3_val,df_ResNet34_fixed_time_lre3_test = create_dfs_fixed_time(logs_folder+"fixed_time_rerun_1004/34/ResNet34_fixed_time_rerun_1004_lre3")
df_ResNet34_fixed_time_lre4_val,df_ResNet34_fixed_time_lre4_test = create_dfs_fixed_time(logs_folder+"fixed_time_rerun_1004/34/ResNet34_fixed_time_rerun_1004_lre4")
df_ResNet34_fixed_time_lre5_val,df_ResNet34_fixed_time_lre5_test = create_dfs_fixed_time(logs_folder+"fixed_time_rerun_1004/34/ResNet34_fixed_time_rerun_1004_lre5")


df_ResNet50_fixed_time_lre3_val,df_ResNet50_fixed_time_lre3_test = create_dfs_fixed_time(logs_folder+"fixed_time_rerun_1004/50/ResNet50_fixed_time_rerun_1004_lre3")
df_ResNet50_fixed_time_lre4_val,df_ResNet50_fixed_time_lre4_test = create_dfs_fixed_time(logs_folder+"fixed_time_rerun_1004/50/ResNet50_fixed_time_rerun_1004_lre4")
df_ResNet50_fixed_time_lre5_val,df_ResNet50_fixed_time_lre5_test = create_dfs_fixed_time(logs_folder+"fixed_time_rerun_1004/50/ResNet50_fixed_time_rerun_1004_lre5")

# %% [markdown]
# ---

# %% [markdown]
# # Validation acc fixed time

# %%
fig_size = (25,8)
plt.figure(figsize= fig_size)
plt.subplot(1,3,1)
plt.plot(100*df_AlexNet_fixed_time_lre3_val['val_accuracy'], label = "AlexNet", color = color_AlexNet)
plt.plot(100*df_ResNet18_fixed_time_lre3_val['val_accuracy'], label = "ResNet18", color = color_ResNet18)
plt.plot(100*df_ResNet34_fixed_time_lre3_val['val_accuracy'], label = "ResNet34", color = color_ResNet34)
plt.plot(100*df_ResNet50_fixed_time_lre3_val['val_accuracy'], label = "ResNet50", color = color_ResNet50)
plt.grid(True)
plt.title('lr = 1e-03')
plt.xlabel('epochs')
plt.ylabel("Validation Accuracy (%)")
plt.ylim(50,100)
plt.legend()

plt.subplot(1,3,2)
plt.plot(100*df_AlexNet_fixed_time_lre4_val['val_accuracy'], label = "AlexNet", color = color_AlexNet)
plt.plot(100*df_ResNet18_fixed_time_lre4_val['val_accuracy'], label = "ResNet18", color = color_ResNet18)
plt.plot(100*df_ResNet34_fixed_time_lre4_val['val_accuracy'], label = "ResNet34", color = color_ResNet34)
plt.plot(100*df_ResNet50_fixed_time_lre4_val['val_accuracy'], label = "ResNet50", color = color_ResNet50)
plt.grid(True)
plt.xlabel('epochs')
plt.ylabel("Validation Accuracy (%)")
plt.title('lr = 1e-04')
plt.ylim(50,100)
plt.legend()

plt.subplot(1,3,3)
plt.plot(100*df_AlexNet_fixed_time_lre5_val['val_accuracy'], label = "AlexNet", color = color_AlexNet)
plt.plot(100*df_ResNet18_fixed_time_lre5_val['val_accuracy'], label = "ResNet18", color = color_ResNet18)
plt.plot(100*df_ResNet34_fixed_time_lre5_val['val_accuracy'], label = "ResNet34", color = color_ResNet34)
plt.plot(100*df_ResNet50_fixed_time_lre5_val['val_accuracy'], label = "ResNet50", color = color_ResNet50)
plt.title('lr = 1e-05')
plt.grid(True)
plt.xlabel('epochs')
plt.ylabel("Validation Accuracy (%)")
plt.ylim(50,100)
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Test Accuracy fixed time

# %%
df_AlexNet_fixed_time_lre3_test['test_accuracy']
# Out:
# 0    0.686965
# 1    0.686965
# 2    0.686965
# Name: test_accuracy, dtype: float64

# %%
fig_size = (25,8)
plt.figure(figsize= fig_size)
plt.subplot(1,3,1)
plt.plot(100*df_AlexNet_fixed_time_lre3_test['val_accuracy'], label = "AlexNet", color = color_AlexNet)
plt.plot(100*df_ResNet18_fixed_time_lre3_val['val_accuracy'], label = "ResNet18", color = color_ResNet18)
plt.plot(100*df_ResNet34_fixed_time_lre3_val['val_accuracy'], label = "ResNet34", color = color_ResNet34)
plt.plot(100*df_ResNet50_fixed_time_lre3_val['val_accuracy'], label = "ResNet50", color = color_ResNet50)
plt.grid(True)
plt.title('lr = 1e-03')
plt.xlabel('epochs')
plt.ylabel("Test Accuracy (%)")
plt.ylim(50,100)
plt.legend()

plt.subplot(1,3,2)
plt.plot(100*df_AlexNet_fixed_time_lre4_val['val_accuracy'], label = "AlexNet", color = color_AlexNet)
plt.plot(100*df_ResNet18_fixed_time_lre4_val['val_accuracy'], label = "ResNet18", color = color_ResNet18)
plt.plot(100*df_ResNet34_fixed_time_lre4_val['val_accuracy'], label = "ResNet34", color = color_ResNet34)
plt.plot(100*df_ResNet50_fixed_time_lre4_val['val_accuracy'], label = "ResNet50", color = color_ResNet50)
plt.grid(True)
plt.xlabel('epochs')
plt.ylabel("Validation Accuracy (%)")
plt.title('lr = 1e-04')
plt.ylim(50,100)
plt.legend()

plt.subplot(1,3,3)
plt.plot(100*df_AlexNet_fixed_time_lre5_val['val_accuracy'], label = "AlexNet", color = color_AlexNet)
plt.plot(100*df_ResNet18_fixed_time_lre5_val['val_accuracy'], label = "ResNet18", color = color_ResNet18)
plt.plot(100*df_ResNet34_fixed_time_lre5_val['val_accuracy'], label = "ResNet34", color = color_ResNet34)
plt.plot(100*df_ResNet50_fixed_time_lre5_val['val_accuracy'], label = "ResNet50", color = color_ResNet50)
plt.title('lr = 1e-05')
plt.grid(True)
plt.xlabel('epochs')
plt.ylabel("Validation Accuracy (%)")
plt.ylim(50,100)
plt.legend()
plt.show()

# %% [markdown]
# # Confusion Matrixs

# %%
conf_matr_path = "/Users/olehbakumenko/PycharmProjects/MasterThesis/Code/confusion_matrix/fixed_time/"
class_names = ['0', '  1', ' 2']
fig_size = (22,7)

# %% [markdown]
# # AlexNet

# %%
plt.figure(figsize = fig_size)
plt.suptitle('AlexNet, lr = 1e-3')

conf_matr = torch.load(conf_matr_path + "AlexNet/confusion_matr_AlexNet_fixed_time_rerun_1004_lre3_10min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,1)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title("10 min", y = 1.02)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "AlexNet/confusion_matr_AlexNet_fixed_time_rerun_1004_lre3_15min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,2)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title("15 min", y = 1.05)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "AlexNet/confusion_matr_AlexNet_fixed_time_rerun_1004_lre3_20min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,3)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title("20 min", y = 1.02)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")
plt.show()

plt.figure(figsize = fig_size)
plt.suptitle('AlexNet, lr = 1e-4')

conf_matr = torch.load(conf_matr_path + "AlexNet/confusion_matr_AlexNet_fixed_time_rerun_1004_lre4_10min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,1)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "AlexNet/confusion_matr_AlexNet_fixed_time_rerun_1004_lre4_15min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,2)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [ {mean_np}]",y = -0.2)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "AlexNet/confusion_matr_AlexNet_fixed_time_rerun_1004_lre4_20min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,3)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

plt.show()


plt.figure(figsize = fig_size)
plt.suptitle('AlexNet, lr = 1e-5')

conf_matr = torch.load(conf_matr_path + "AlexNet/confusion_matr_AlexNet_fixed_time_rerun_1004_lre5_10min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,1)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "AlexNet/confusion_matr_AlexNet_fixed_time_rerun_1004_lre5_15min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,2)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [ {mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "AlexNet/confusion_matr_AlexNet_fixed_time_rerun_1004_lre5_20min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,3)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # ResNet18

# %%
plt.figure(figsize = fig_size)
plt.suptitle('ResNet18, lr = 1e-3')

conf_matr = torch.load(conf_matr_path + "18/confusion_matr_ResNet18_fixed_time_rerun_1004_lre3_10min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,1)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title("10 min", y = 1.02)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "18/confusion_matr_ResNet18_fixed_time_rerun_1004_lre3_15min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,2)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title("15 min", y = 1.02)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [ {mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "18/confusion_matr_ResNet18_fixed_time_rerun_1004_lre3_20min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,3)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title("20 min", y = 1.02)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")
plt.show()


plt.figure(figsize = fig_size)
plt.suptitle('ResNet18, lr = 1e-4')

conf_matr = torch.load(conf_matr_path + "18/confusion_matr_ResNet18_fixed_time_rerun_1004_lre4_10min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,1)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "18/confusion_matr_ResNet18_fixed_time_rerun_1004_lre4_15min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,2)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [ {mean_np}]",y = -0.2)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "18/confusion_matr_ResNet18_fixed_time_rerun_1004_lre4_20min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,3)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")
plt.show()

plt.figure(figsize = fig_size)
plt.suptitle('ResNet18, lr = 1e-5')

conf_matr = torch.load(conf_matr_path + "18/confusion_matr_ResNet18_fixed_time_rerun_1004_lre5_10min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,1)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "18/confusion_matr_ResNet18_fixed_time_rerun_1004_lre5_15min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,2)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [ {mean_np}]",y = -0.2)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "18/confusion_matr_ResNet18_fixed_time_rerun_1004_lre5_20min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,3)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")


plt.show()

# %% [markdown]
# ----

# %% [markdown]
# # ResNet34

# %%
plt.figure(figsize = fig_size)
plt.suptitle('ResNet34, lr = 1e-3')

conf_matr = torch.load(conf_matr_path + "34/confusion_matr_ResNet34_fixed_time_rerun_1004_lre3_10min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,1)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title("10 min", y = 1.02)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "34/confusion_matr_ResNet34_fixed_time_rerun_1004_lre3_15min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,2)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title("15 min", y = 1.02)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [ {mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "34/confusion_matr_ResNet34_fixed_time_rerun_1004_lre3_20min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,3)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title("20 min", y = 1.02)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")


plt.show()

plt.figure(figsize = fig_size)
plt.suptitle('ResNet34, lr = 1e-4')

conf_matr = torch.load(conf_matr_path + "34/confusion_matr_ResNet34_fixed_time_rerun_1004_lre4_10min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,1)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "34/confusion_matr_ResNet34_fixed_time_rerun_1004_lre4_15min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,2)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [ {mean_np}]",y = -0.2)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "34/confusion_matr_ResNet34_fixed_time_rerun_1004_lre4_20min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,3)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

plt.show()

plt.figure(figsize = fig_size)
plt.suptitle('ResNet34, lr = 1e-5')

conf_matr = torch.load(conf_matr_path + "34/confusion_matr_ResNet34_fixed_time_rerun_1004_lre5_10min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,1)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "34/confusion_matr_ResNet34_fixed_time_rerun_1004_lre5_15min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,2)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [ {mean_np}]",y = -0.2)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "34/confusion_matr_ResNet34_fixed_time_rerun_1004_lre5_20min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,3)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # ResNet50

# %%
plt.figure(figsize = fig_size)
plt.suptitle('ResNet50, lr = 1e-3')

conf_matr = torch.load(conf_matr_path + "50/confusion_matr_ResNet50_fixed_time_rerun_1004_lre3_10min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,1)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title("10 min", y = 1.02)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "50/confusion_matr_ResNet50_fixed_time_rerun_1004_lre3_15min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,2)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title("15 min", y = 1.02)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [ {mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "50/confusion_matr_ResNet50_fixed_time_rerun_1004_lre3_20min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,3)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title("20 min", y = 1.02)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")
plt.show()

plt.figure(figsize = fig_size)
plt.suptitle('ResNet50, lr = 1e-4')

conf_matr = torch.load(conf_matr_path + "50/confusion_matr_ResNet50_fixed_time_rerun_1004_lre4_10min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,1)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "50/confusion_matr_ResNet50_fixed_time_rerun_1004_lre4_15min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,2)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [ {mean_np}]",y = -0.2)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "50/confusion_matr_ResNet50_fixed_time_rerun_1004_lre4_20min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,3)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")
plt.show()

plt.figure(figsize = fig_size)
plt.suptitle('ResNet50, lr = 1e-5')

conf_matr = torch.load(conf_matr_path + "50/confusion_matr_ResNet50_fixed_time_rerun_1004_lre5_10min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,1)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "50/confusion_matr_ResNet50_fixed_time_rerun_1004_lre5_15min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,2)
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [ {mean_np}]",y = -0.2)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.xlabel("Prediction")
plt.ylabel("Target")

conf_matr = torch.load(conf_matr_path + "50/confusion_matr_ResNet50_fixed_time_rerun_1004_lre5_20min.pt")
per_class_accuracy = 100*conf_matr.diag()/conf_matr.sum(1)
mean = torch.mean(per_class_accuracy)
per_class_accuracy_np = np.array2string(np.round(per_class_accuracy.detach().numpy(),2), separator=' ; ')
mean_np = np.array2string(np.round(mean.detach().numpy(),2))
df_cm = pd.DataFrame(conf_matr, class_names, class_names)
plt.subplot(1,3,3)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.title(f"Per class  accuracy:  { per_class_accuracy_np}, Mean: [{mean_np}]",y = -0.2)
plt.xlabel("Prediction")
plt.ylabel("Target")

plt.show()
