# %% [markdown]
# # Plots

# %%
import sys
#sys.path.append("/datashare/MLCourse/Course_Materials") # Preferentially import from the datashare.
sys.path.append("../") # Otherwise, import from the local folder's parent folder, where your stuff lives.

import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import torch, torch.nn as nn
import torchvision, torchvision.transforms as tt
from torch.multiprocessing import Manager
torch.multiprocessing.set_sharing_strategy("file_system")

# %%
import os
from os.path import exists
import pandas as pd

# creates a pandas dataframe if file exist
def create_df_if_exist(path):
    if exists(path):
        return pd.read_csv(path, sep=',')
    else:
        print('No file exist', path)
        return None

# creates 4 dataframes, with validate, train, test and runtime logs.
def create_dfs_filename(path):
    path_val = path + '_val.csv'
    path_train =  path + '_train.csv'
    path_test = path + '_test.csv'
    path_runtime = path + '_runtime.csv'

    return create_df_if_exist(path_val), create_df_if_exist(path_train), create_df_if_exist(path_test), create_df_if_exist(path_runtime)

# %%
logs_folder = '/home/coder/Course_Materials/logs/'

if not os.path.isdir(logs_folder):
    #logs_folder = '/Users/olehbakumenko/PycharmProjects/Git/Course_Materials/logs/'
    logs_folder = '/Users/olehbakumenko/PycharmProjects/MasterThesis/logs/'

# %%
logs_folder
# Out:
# '/Users/olehbakumenko/PycharmProjects/MasterThesis/logs/'

# %%
filename = 'AlexNet'
df_AlexNet_val, df_AlexNet_train, df_AlexNet_test, df_AlexNet_runtime = create_dfs_filename(logs_folder+filename)

# %%
filename = 'ResNet18'
df_ResNet18_val, df_ResNet18_train, df_ResNet18_test, df_ResNet18_runtime = create_dfs_filename(logs_folder+filename)

# %%
filename = 'ResNet34'
df_ResNet34_val, df_ResNet34_train, df_ResNet34_test, df_ResNet34_runtime = create_dfs_filename(logs_folder+filename)

# %%
filename = 'ResNet34_init'
df_ResNet34_init_val, df_ResNet34_init_train, df_ResNet34_init_test, df_ResNet34_init_runtime = create_dfs_filename(logs_folder+filename)

# %%
filename = 'ResNet50'
df_ResNet50_val, df_ResNet50_train, df_ResNet50_test, df_ResNet50_runtime = create_dfs_filename(logs_folder+filename)

# %%
filename = 'ResNet50_init'
df_ResNet50_init_val, df_ResNet50_init_train, df_ResNet50_init_test, df_ResNet50_init_runtime = create_dfs_filename(logs_folder+filename)

# %%
filename = 'ResNet152_rand'
df_ResNet152_val, df_ResNet152_train, df_ResNet152_test, df_ResNet152_runtime = create_dfs_filename(logs_folder+filename)
# Out:
# No file exist /Users/olehbakumenko/PycharmProjects/MasterThesis/logs/ResNet152_rand_runtime.csv

# %%
filename = 'ResNet152_init'
df_ResNet152_init_val, df_ResNet152_init_train, df_ResNet152_init_test, df_ResNet152_init_runtime = create_dfs_filename(logs_folder+filename)

# %%
filename = 'VGG19'
df_VGG19_val, df_VGG19_train, df_VGG19_test, df_VGG19_runtime = create_dfs_filename(logs_folder+filename)

# %%
filename = 'ResNet34_plain/ResNet34_plain_1'
df_ResNet34_plain_1_val, df_ResNet34_plain_1_train, df_ResNet34_plain_1_test, df_ResNet34_plain_1_runtime = create_dfs_filename(logs_folder+filename)
filename = 'ResNet34_plain/ResNet34_plain_2'
df_ResNet34_plain_2_val, df_ResNet34_plain_2_train, df_ResNet34_plain_2_test, df_ResNet34_plain_2_runtime = create_dfs_filename(logs_folder+filename)
filename = 'ResNet34_plain/ResNet34_plain_3'
df_ResNet34_plain_3_val, df_ResNet34_plain_3_train, df_ResNet34_plain_3_test, df_ResNet34_plain_3_runtime = create_dfs_filename(logs_folder+filename)

# %%
val_accuracy = pd.DataFrame()
val_accuracy['AlexNet'] = df_AlexNet_val['val_accuracy']
val_accuracy['ResNet18'] = df_ResNet18_val['val_accuracy']
val_accuracy['ResNet34'] = df_ResNet34_val['val_accuracy']
val_accuracy['ResNet34_init'] = df_ResNet34_init_val['val_accuracy']
val_accuracy['ResNet50'] = df_ResNet50_val['val_accuracy']
val_accuracy['ResNet50_init'] = df_ResNet50_init_val['val_accuracy']
val_accuracy['ResNet152'] = df_ResNet152_val['val_accuracy']
val_accuracy['ResNet152_init'] = df_ResNet152_init_val['val_accuracy']
val_accuracy['VGG19'] = df_VGG19_val['val_accuracy']
val_accuracy = val_accuracy.mul(100)

# %%
val_loss = pd.DataFrame()
val_loss['AlexNet'] = df_AlexNet_val['val_loss']
val_loss['ResNet18'] = df_ResNet18_val['val_loss']
val_loss['ResNet34'] = df_ResNet34_val['val_loss']
val_loss['ResNet34_init'] = df_ResNet34_init_val['val_loss']
val_loss['ResNet50'] = df_ResNet50_val['val_loss']
val_loss['ResNet50_init'] = df_ResNet50_init_val['val_loss']
val_loss['ResNet152'] = df_ResNet152_val['val_loss']
val_loss['ResNet152_init'] = df_ResNet152_init_val['val_loss']
val_loss['VGG19'] = df_VGG19_val['val_loss']

# %%
test_accuracy = pd.DataFrame()
test_accuracy['AlexNet'] = df_AlexNet_test['test_accuracy']
test_accuracy['ResNet18'] = df_ResNet18_test['test_accuracy']
test_accuracy['ResNet34'] = df_ResNet34_test['test_accuracy']
test_accuracy['ResNet34_init'] = df_ResNet34_init_test['test_accuracy']
test_accuracy['ResNet50'] = df_ResNet50_test['test_accuracy']
test_accuracy['ResNet50_init'] = df_ResNet50_init_test['test_accuracy']
test_accuracy['ResNet152'] = df_ResNet152_test['test_accuracy']
test_accuracy['ResNet152_init'] = df_ResNet152_init_test['test_accuracy']
test_accuracy['VGG19'] = df_VGG19_test['test_accuracy']
test_accuracy = test_accuracy.mul(100)

# %%
test_loss = pd.DataFrame()
test_loss['AlexNet'] = df_AlexNet_test['test_loss']
test_loss['ResNet18'] = df_ResNet18_test['test_loss']
test_loss['ResNet34'] = df_ResNet34_test['test_loss']
test_loss['ResNet34_init'] = df_ResNet34_init_test['test_loss']
test_loss['ResNet50'] = df_ResNet50_test['test_loss']
test_loss['ResNet50_init'] = df_ResNet50_init_test['test_loss']
test_loss['ResNet152'] = df_ResNet152_test['test_loss']
test_loss['ResNet152_init'] = df_ResNet152_init_test['test_loss']
test_loss['VGG19'] = df_VGG19_test['test_loss']

# %%
runtime = pd.DataFrame()
runtime['AlexNet'] = df_AlexNet_runtime['runtime']
runtime['ResNet18'] = df_ResNet18_runtime['runtime']
runtime['ResNet34'] = df_ResNet34_runtime['runtime']
runtime['ResNet34_init'] = df_ResNet34_init_runtime['runtime']
runtime['ResNet50'] = df_ResNet50_runtime['runtime']
runtime['ResNet50_init'] = df_ResNet50_init_runtime['runtime']
runtime['ResNet152_init'] = df_ResNet152_init_runtime['runtime']
runtime['VGG19'] = df_VGG19_runtime['runtime']

# %%
runtime
# Out:
#     AlexNet   ResNet18  ResNet34  ResNet34_init  ResNet50  ResNet50_init  \
# 0   37.0645  79.397459   67.0968        66.2340  116.7267       117.1199
# 1   36.2678  59.737961   66.5149        66.1618  116.3554       117.6898
# 2   36.0199  62.147742   68.9349        68.4098  118.5703       119.4283
# 3   36.4368  64.867470   70.1204        69.4919  120.7054       120.3067
# 4   36.3809  65.353594   70.0495        69.8226  120.3633       120.2412
# 5   36.2575  64.609499   70.6642        69.5372  119.9661       120.3367
# 6   36.5494  66.485573   70.5195        69.5599  120.1012       120.3372
# 7   36.4601  65.695114   70.5830        70.7735  119.6660       120.0245
# 8   36.3642  65.367815   70.5448        70.8493  120.0938       119.7253
# 9   36.7667  65.768031   70.3629        70.4437  119.5750       119.3585
# 10  36.5704  64.987537   70.3267        70.0158  119.3875       119.1398
# 11  36.3645  64.424763   71.6750        70.1445  119.4301       119.2334
# ...

# %%
train_loss_AlexNet = df_AlexNet_train['loss'].to_numpy()
train_loss_ResNet18 = df_ResNet18_train['loss'].to_numpy()
train_loss_ResNet34 = df_ResNet34_train['loss'].to_numpy()
train_loss_ResNet34_init = df_ResNet34_init_train['loss'].to_numpy()
train_loss_ResNet50 = df_ResNet50_train['loss'].to_numpy()
train_loss_ResNet50_init = df_ResNet50_init_train['loss'].to_numpy()
train_loss_ResNet152_init = df_ResNet152_init_train['loss'].to_numpy()
train_loss_VGG = df_VGG19_train['loss'].to_numpy()

# %%
val_accuracy_ResNet34_plain_1 = df_ResNet34_plain_1_val['val_accuracy'].to_numpy()*100
val_accuracy_ResNet34_plain_2 = df_ResNet34_plain_2_val['val_accuracy'].to_numpy()*100
val_accuracy_ResNet34_plain_3 = df_ResNet34_plain_3_val['val_accuracy'].to_numpy()*100
val_accuracy_ResNet34_plain_avarage = (val_accuracy_ResNet34_plain_1+val_accuracy_ResNet34_plain_1+val_accuracy_ResNet34_plain_1)/3

# %%
val_loss_ResNet34_plain_1 = df_ResNet34_plain_1_val['val_loss'].to_numpy()
val_loss_ResNet34_plain_2 = df_ResNet34_plain_2_val['val_loss'].to_numpy()
val_loss_ResNet34_plain_3 = df_ResNet34_plain_3_val['val_loss'].to_numpy()
val_loss_ResNet34_plain_avarage = (val_loss_ResNet34_plain_1+val_loss_ResNet34_plain_2+val_loss_ResNet34_plain_3)/3

# %%
plt.plot(val_accuracy['ResNet18'], label = "ResNet18" )
plt.plot(val_accuracy['ResNet34'], label = "ResNet34" )
plt.plot(val_accuracy_ResNet34_plain_avarage, label = "ResNet34 plain avarage" )
plt.plot(val_accuracy['AlexNet'], label = "AlexNet")


plt.grid()
plt.xlabel('epochs')
plt.title("Validation Accuracy (%)")
plt.ylim(50,100)
plt.legend()
plt.show()

# %%
plt.plot(val_accuracy['ResNet18'], label = "ResNet18" )
plt.plot(val_accuracy['ResNet34'], label = "ResNet34" )
#plt.plot(val_accuracy['AlexNet'], label = "AlexNet")
#plt.plot(val_accuracy['VGG19'], label = "VGG19" )
plt.plot(val_accuracy['ResNet50'], label = "ResNet50" )
#plt.plot(val_accuracy['ResNet152'], label = "ResNet152" )
#plt.plot(val_accuracy['ResNet18'], label = "ResNet18" )


#plt.plot(val_accuracy_ResNet34_plain_avarage, label = "ResNet34 plain avarage" )

plt.grid()
plt.xlabel('epochs')
plt.title("Validation Accuracy (%)")
plt.ylim(75,100)
plt.legend()
plt.show()

# %%
plt.plot(val_loss['AlexNet'], label = "AlexNet")
plt.plot(val_loss['VGG19'] , label = "VGG19" )
plt.plot(val_loss['ResNet18'] , label = "ResNet18")
plt.plot(val_loss['ResNet34'], label = "ResNet34")
plt.plot(val_loss['ResNet50'], label = "ResNet50")
#plt.plot(val_loss_ResNet152, label = "ResNet152")

plt.grid()
plt.xlabel('epochs')
plt.title("Avarage Validation Loss")
plt.ylim(0,0.6)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
plt.plot(val_accuracy['ResNet18'], label = "ResNet18" )
plt.plot(val_accuracy['ResNet34'], label = "ResNet34" )
#plt.plot(val_accuracy['AlexNet'], label = "AlexNet")
#plt.plot(val_accuracy['VGG19'], label = "VGG19" )
plt.plot(val_accuracy['ResNet50'], label = "ResNet50" )
#plt.plot(val_accuracy['ResNet152'], label = "ResNet152" )
#plt.plot(val_accuracy['ResNet18'], label = "ResNet18" )

plt.grid()
plt.xlabel('epochs')
plt.title("Validation Accuracy (%)")
plt.ylim(75,100)
plt.legend()

#plt.figure(figsize=(10, 5))
plt.subplot(1,2,2)
#plt.plot(val_loss['AlexNet'], label = "AlexNet")
#plt.plot(val_loss['VGG19'] , label = "VGG19" )
plt.plot(val_loss['ResNet18'] , label = "ResNet18")
plt.plot(val_loss['ResNet34'], label = "ResNet34")
plt.plot(val_loss['ResNet50'], label = "ResNet50")
#plt.plot(val_loss_ResNet152, label = "ResNet152")

plt.grid()
plt.xlabel('epochs')
plt.title("Avarage Validation Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
plt.plot(val_accuracy['ResNet34'], label = "ResNet34" )
plt.plot(val_accuracy_ResNet34_plain_avarage, label = "ResNet34 plain" )

plt.grid()
plt.xlabel('epochs')
plt.title("Validation Accuracy (%)")
plt.ylim(50,100)
plt.legend()

#plt.figure(figsize=(10, 5))
plt.subplot(1,2,2)
plt.plot(val_loss['ResNet34'], label = "ResNet34")
plt.plot(val_loss_ResNet34_plain_avarage, label = "ResNet34 plain")
plt.grid()
plt.xlabel('epochs')
plt.title("Avarage Validation Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
plt.plot(val_accuracy['ResNet34'], label = "ResNet34" )
plt.plot(val_accuracy['ResNet18'], label = "ResNet18" )

plt.grid()
plt.xlabel('epochs')
plt.title("Validation Accuracy (%)")
plt.ylim(50,100)
plt.legend()

plt.subplot(1,2,2)
plt.plot(val_loss['ResNet34'], label = "ResNet34")
plt.plot(val_loss['ResNet18'], label = "ResNet18")
plt.grid()
plt.xlabel('epochs')
plt.title("Avarage Validation Loss")
plt.ylim(0,1)
plt.legend()
plt.show()

# %% [markdown]
# ____________________

# %% [markdown]
# # Train loss landscape

# %%
train_loss_AlexNet_tensor = np.array(train_loss_AlexNet)
train_loss_AlexNet_tensor = torch.tensor(train_loss_AlexNet_tensor).view(15,-1)
mean_train_loss_AlexNet = train_loss_AlexNet_tensor.mean(1,True)

train_loss_ResNet18_tensor = np.array(train_loss_ResNet18)
train_loss_ResNet18_tensor = torch.tensor(train_loss_ResNet18_tensor).view(15,-1)
mean_train_loss_ResNet18 = train_loss_ResNet18_tensor.mean(1,True)

train_loss_ResNet34_tensor = np.array(train_loss_ResNet34)
train_loss_ResNet34_tensor = torch.tensor(train_loss_ResNet34_tensor).view(15,-1)
mean_train_loss_ResNet34 = train_loss_ResNet34_tensor.mean(1,True)

train_loss_ResNet50_tensor = np.array(train_loss_ResNet50)
train_loss_ResNet50_tensor = torch.tensor(train_loss_ResNet50_tensor).view(15,-1)
mean_train_loss_ResNet50 = train_loss_ResNet50_tensor.mean(1,True)

train_loss_VGG_tensor = np.array(train_loss_VGG)
train_loss_VGG_tensor = torch.tensor(train_loss_VGG_tensor).view(15,-1)
mean_train_loss_VGG19 = train_loss_VGG_tensor.mean(1,True)

# %%
plt.plot(mean_train_loss_AlexNet, label = "AlexNet")
plt.plot(mean_train_loss_ResNet18, label = "ResNet18")
plt.plot(mean_train_loss_ResNet34, label = "ResNet34")
plt.plot(mean_train_loss_ResNet50, label = "ResNet50")
plt.plot(mean_train_loss_VGG19, label = "VGG19" )


plt.grid()
plt.xlabel('epochs')
plt.title("Mean train loss")
plt.ylim(0,0.6)
plt.legend()
plt.show()

# %% [markdown]
# # Lets compare the same with val loss

# %%
plt.figure(figsize=(12, 9))

plt.subplot(2,2,1)
plt.plot(mean_train_loss_AlexNet, label = "AlexNet train")
plt.plot(val_loss['AlexNet'], label = "AlexNet val")
plt.grid()
#plt.xlabel('epochs')
plt.ylabel('train vs. val loss')
plt.ylim(0,0.6)
plt.legend()

plt.subplot(2,2,2)
plt.plot(mean_train_loss_ResNet34, label = "ResNet34 train")
plt.plot(val_loss['ResNet34'], label = "ResNet34 val")
plt.grid()
#plt.xlabel('epochs')
plt.ylim(0,0.6)
plt.legend()


plt.subplot(2,2,3)
plt.plot(mean_train_loss_ResNet50, label = "ResNet50 train")
plt.plot(val_loss['ResNet50'], label = "ResNet50 val")
plt.grid()
plt.xlabel('epochs')
plt.ylabel('train vs. val loss')
plt.ylim(0,0.6)
plt.legend()



plt.subplot(2,2,4)
plt.plot(mean_train_loss_VGG19, label = "VGG19 train" )
plt.plot(val_loss['VGG19'], label = "VGG19 val")
plt.grid()
plt.xlabel('epochs')
plt.ylim(0,0.6)
plt.legend()

plt.show()

# %% [markdown]
# # The same but only ResNets

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1,3,1)
plt.plot(mean_train_loss_ResNet18, label = "ResNet18 train")
plt.plot(val_loss['ResNet18'], label = "ResNet18 val")
plt.grid()
plt.xlabel('epochs')
plt.ylabel('train vs. val loss')
plt.ylim(0,0.6)
plt.legend()

plt.subplot(1,3,2)
plt.plot(mean_train_loss_ResNet34, label = "ResNet34 train")
plt.plot(val_loss['ResNet34'], label = "ResNet34 val")
plt.grid()
plt.xlabel('epochs')
#plt.ylabel('train vs. val loss')
plt.ylim(0,0.6)
plt.legend()


plt.subplot(1,3,3)
plt.plot(mean_train_loss_ResNet50, label = "ResNet50 train")
plt.plot(val_loss['ResNet50'], label = "ResNet50 val")
plt.grid()
plt.xlabel('epochs')
#plt.ylabel('train vs. val loss')
plt.ylim(0,0.6)
plt.legend()


plt.show()

# %% [markdown]
# -----

# %% [markdown]
# # Summ of losses in epoch

# %%
train_loss_AlexNet_sum_epochs= torch.sum(train_loss_AlexNet_tensor,dim=1)
train_loss_ResNet18_sum_epochs= torch.sum(train_loss_ResNet18_tensor,dim=1)
train_loss_ResNet34_sum_epochs= torch.sum(train_loss_ResNet34_tensor,dim=1)
train_loss_ResNet50_sum_epochs= torch.sum(train_loss_ResNet50_tensor,dim=1)
train_loss_VGG_sum_epochs= torch.sum(train_loss_VGG_tensor,dim=1)

# %%
plt.plot(train_loss_AlexNet_sum_epochs, label = "AlexNet")
plt.plot(train_loss_ResNet34_sum_epochs, label = "ResNet34" )
plt.plot(train_loss_ResNet18_sum_epochs, label = "ResNet18" )
plt.plot(train_loss_ResNet50_sum_epochs, label = "ResNet50")
plt.plot(train_loss_VGG_sum_epochs, label = "VGG")

plt.grid()
plt.xlabel('epochs')
plt.title("Sum train loss")
#plt.ylim(0,0.5)
plt.legend()
plt.show()

# %% [markdown]
# ------

# %% [markdown]
# # Mean of a fixed numer of elements in each epoch

# %%
num_mesurements = 50

train_loss_AlexNet_tensor = np.array(train_loss_AlexNet)
train_loss_AlexNet_tensor = torch.tensor(train_loss_AlexNet_tensor).view(15,-1)
train_loss_AlexNet_tensor = train_loss_AlexNet_tensor[:,0:1000]
train_loss_AlexNet_tensor = train_loss_AlexNet_tensor.view(15,num_mesurements,-1)
train_loss_AlexNet_tensor= torch.mean(train_loss_AlexNet_tensor,2,True).view(-1)



train_loss_ResNet18_tensor = np.array(train_loss_ResNet18)
train_loss_ResNet18_tensor = torch.tensor(train_loss_ResNet18_tensor).view(15,-1)
train_loss_ResNet18_tensor = train_loss_ResNet18_tensor[:,0:1000]
train_loss_ResNet18_tensor = train_loss_ResNet18_tensor.view(15,num_mesurements,-1)
train_loss_ResNet18_tensor= torch.mean(train_loss_ResNet18_tensor,2,True).view(-1)



train_loss_ResNet34_tensor = np.array(train_loss_ResNet34)
train_loss_ResNet34_tensor = torch.tensor(train_loss_ResNet34_tensor).view(15,-1)
train_loss_ResNet34_tensor = train_loss_ResNet34_tensor[:,0:1000]
train_loss_ResNet34_tensor = train_loss_ResNet34_tensor.view(15,num_mesurements,-1)
train_loss_ResNet34_tensor= torch.mean(train_loss_ResNet34_tensor,2,True).view(-1)


train_loss_ResNet50_tensor = np.array(train_loss_ResNet50)
train_loss_ResNet50_tensor = torch.tensor(train_loss_ResNet50_tensor).view(15,-1)
train_loss_ResNet50_tensor = train_loss_ResNet50_tensor[:,0:1000]
train_loss_ResNet50_tensor = train_loss_ResNet50_tensor.view(15,num_mesurements,-1)
train_loss_ResNet50_tensor= torch.mean(train_loss_ResNet50_tensor,2,True).view(-1)


train_loss_VGG_tensor = np.array(train_loss_VGG)
train_loss_VGG_tensor = torch.tensor(train_loss_VGG_tensor).view(15,-1)
train_loss_VGG_tensor = train_loss_VGG_tensor[:,0:1000]
train_loss_VGG_tensor = train_loss_VGG_tensor.view(15,num_mesurements,-1)
train_loss_VGG_tensor= torch.mean(train_loss_VGG_tensor,2,True).view(-1)

# %%
linewidth = 0.8
#plt.figure(figsize=(15, 5))
#plt.plot(train_loss_AlexNet_tensor, label = "AlexNet",linewidth=linewidth)
plt.plot(train_loss_ResNet18_tensor, label = "ResNet34",linewidth=linewidth)
plt.plot(train_loss_ResNet34_tensor, label = "ResNet34",linewidth=linewidth)
plt.plot(train_loss_ResNet50_tensor, label = "ResNet50",linewidth=linewidth)
#plt.plot(train_loss_VGG_tensor, label = "VGG",linewidth=linewidth)

plt.grid()
plt.title("Train loss landscape")
#lt.xlabel('steps')
#plt.xlim(0,10^5)
#plt.yscale('log')
plt.legend()
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# # More Experements

# %% [markdown]
# # Figure: accuracy, validation and train loss ResNet ResNet plain, AlexNet,

# %%
plt.plot(val_accuracy['AlexNet'], label = "AlexNet")
plt.plot(val_accuracy['ResNet34'], label = "ResNet34")
plt.plot(val_accuracy_ResNet34_plain_avarage, label = "ResNet34 plain")
plt.grid()
plt.xlabel('epochs')
plt.ylabel("Validation Accuracy (%)")
plt.ylim(50,100)
plt.legend()
plt.show()

# %%
train_loss_ResNet_plain = df_ResNet34_plain_1_train['loss'].to_numpy()
train_loss_ResNet_plain_tensor = np.array(train_loss_ResNet_plain)
train_loss_ResNet_plain_tensor = torch.tensor(train_loss_ResNet_plain_tensor).view(15,-1)
mean_train_loss_ResNet_plain = train_loss_ResNet_plain_tensor.mean(dim=1).detach().numpy()

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1,2,1)
plt.plot(mean_train_loss_AlexNet, label = "AlexNet")
plt.plot(mean_train_loss_ResNet34, label = "ResNet34")
plt.plot(mean_train_loss_ResNet_plain, label = "ResNet34 plain")

plt.grid()
plt.xlabel('epochs')
plt.ylabel("Avarage Train Loss")
plt.ylim(0,0.7)
plt.legend()

plt.subplot(1,2,2)
plt.plot(val_loss['AlexNet'], label = "AlexNet")
plt.plot(val_loss['ResNet34'], label = "ResNet34")
plt.plot(val_loss_ResNet34_plain_avarage, label = "ResNet34 plain")
plt.grid()
plt.xlabel('epochs')
plt.ylabel("Avarage Validation Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1,3,1)
plt.plot(val_accuracy['AlexNet'], label = "AlexNet")
plt.plot(val_accuracy['ResNet34'], label = "ResNet34")
plt.plot(val_accuracy_ResNet34_plain_avarage, label = "ResNet34 plain")
plt.grid()
plt.xlabel('epochs')
plt.ylabel("Validation Accuracy (%)")
plt.ylim(50,100)
plt.legend()

plt.subplot(1,3,2)
plt.plot(mean_train_loss_AlexNet, label = "AlexNet")
plt.plot(mean_train_loss_ResNet34, label = "ResNet34")
plt.plot(mean_train_loss_ResNet_plain, label = "ResNet34 plain")

plt.grid()
plt.xlabel('epochs')
plt.ylabel("Avarage Train Loss")
plt.ylim(0,0.7)
plt.legend()

plt.subplot(1,3,3)
plt.plot(val_loss['AlexNet'], label = "AlexNet")
plt.plot(val_loss['ResNet34'], label = "ResNet34")
plt.plot(val_loss_ResNet34_plain_avarage, label = "ResNet34 plain")
plt.grid()
plt.xlabel('epochs')
plt.ylabel("Avarage Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# # Testing initializations

# %% [markdown]
# # Using AdamW

# %% [markdown]
# # ResNet18 vs ResNet18 init

# %%
filename = 'test/ResNet18_noinit'
df_ResNet18_noinit_val, df_ResNet18_noinit_train, df_ResNet18_noinit_test, df_ResNet18_noinit_runtime = create_dfs_filename(logs_folder+filename)

# %%
df_ResNet18_noinit_test
# Out:
#    epoch  test_loss  test_accuracy
# 0     14   0.059488       0.981567

# %%
val_accuracy['ResNet18_noinit'] = df_ResNet18_noinit_val['val_accuracy']
val_loss['ResNet18_noinit'] =  df_ResNet18_noinit_val['val_loss']
test_accuracy['ResNet18_noinit'] = df_ResNet18_noinit_test['test_accuracy']
test_loss['ResNet18_noinit'] = df_ResNet18_noinit_test['test_loss']
runtime['ResNet18_noinit'] = df_ResNet18_noinit_runtime['runtime']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/PycharmProjects/MasterThesis/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/PycharmProjects/MasterThesis/venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/PycharmProjects/MasterThesis/venv/lib/python3.8/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'val_accuracy'
#
# ...

# %%
plt.plot(val_accuracy['ResNet50'], label = "ResNet50" )
plt.plot(val_accuracy['ResNet50_init'], label = "ResNet50_init" )
plt.title("Validation Accuracy")
plt.xlabel('epochs')
plt.legend()
plt.grid()
plt.ylim(50, 100)
plt.show()

plt.plot(val_loss['ResNet50'], label = "ResNet50")
plt.plot(val_loss['ResNet50_init'], label = "ResNet50_init")
plt.grid()
plt.legend()
plt.xlabel('epochs')
plt.title("Avarage Validation Loss")
plt.ylim(0, 1)

plt.show()

plt.plot(runtime['ResNet50'], label = "ResNet50")
plt.plot(runtime['ResNet50_init'], label = "ResNet50init")
plt.grid()
plt.legend()
plt.xlabel('epochs')
plt.title("Runtime")
plt.ylim(80, 150)
plt.show()
height = [test_accuracy['ResNet50'].item(),test_accuracy['ResNet50_init'].item()]

bars = ('ResNet50','ResNet50_init')
y_pos = np.arange(len(bars))
fig, ax = plt.subplots()
vbars = ax.bar(y_pos, height,color=colors)
ax.bar_label(vbars, fmt='%.2f')
plt.bar(y_pos, height,color=colors)
plt.ylim(0, 100)
plt.xticks(y_pos, bars)
plt.title("Test Accuracy (%)")
plt.grid()
plt.show()

height = [test_loss['ResNet50'].item(),test_loss['ResNet50_init'].item()]
bars = ('ResNet50','ResNet50init')
y_pos = np.arange(len(bars))
fig, ax = plt.subplots()
vbars = ax.bar(y_pos, height,color=colors)
ax.bar_label(vbars, fmt='%.2f')
plt.bar(y_pos, height,color=colors)
plt.xticks(y_pos, bars)
plt.title("Test Loss")
plt.grid()
plt.show()

# %% [markdown]
# # ResNet50 vs ResNet50 init

# %%
colors = ['blue', 'orange', 'limegreen', 'red']

# %%
plt.plot(val_accuracy['ResNet50'], label = "ResNet50" )
plt.plot(val_accuracy['ResNet50_init'], label = "ResNet50_init" )
plt.title("Validation Accuracy")
plt.xlabel('epochs')
plt.legend()
plt.grid()
plt.ylim(50, 100)
plt.show()

plt.plot(val_loss['ResNet50'], label = "ResNet50")
plt.plot(val_loss['ResNet50_init'], label = "ResNet50_init")
plt.grid()
plt.legend()
plt.xlabel('epochs')
plt.title("Avarage Validation Loss")
plt.ylim(0, 1)

plt.show()

plt.plot(runtime['ResNet50'], label = "ResNet50")
plt.plot(runtime['ResNet50_init'], label = "ResNet50init")
plt.grid()
plt.legend()
plt.xlabel('epochs')
plt.title("Runtime")
plt.ylim(80, 150)
plt.show()
height = [test_accuracy['ResNet50'].item(),test_accuracy['ResNet50_init'].item()]

bars = ('ResNet50','ResNet50_init')
y_pos = np.arange(len(bars))
fig, ax = plt.subplots()
vbars = ax.bar(y_pos, height,color=colors)
ax.bar_label(vbars, fmt='%.2f')
plt.bar(y_pos, height,color=colors)
plt.ylim(0, 100)
plt.xticks(y_pos, bars)
plt.title("Test Accuracy (%)")
plt.grid()
plt.show()

height = [test_loss['ResNet50'].item(),test_loss['ResNet50_init'].item()]
bars = ('ResNet50','ResNet50init')
y_pos = np.arange(len(bars))
fig, ax = plt.subplots()
vbars = ax.bar(y_pos, height,color=colors)
ax.bar_label(vbars, fmt='%.2f')
plt.bar(y_pos, height,color=colors)
plt.xticks(y_pos, bars)
plt.title("Test Loss")
plt.grid()
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# # ResNet34 vs ResNet34 init

# %%
plt.plot(val_accuracy['ResNet34'], label = "ResNet34" )
plt.plot(val_accuracy['ResNet34_init'], label = "ResNet34_init" )
plt.title("Validation Accuracy")
plt.xlabel('epochs')
plt.legend()
plt.grid()
plt.ylim(50, 100)

plt.show()

#----------------

plt.plot(val_loss['ResNet34'], label = "ResNet34")
plt.plot(val_loss['ResNet34_init'], label = "ResNet34_init")
plt.grid()
plt.legend()
plt.xlabel('epochs')
plt.title("Avarage Validation Loss")
plt.ylim(0, 1)

plt.show()

#----------------
plt.plot(runtime['ResNet34'], label = "ResNet34")
plt.plot(runtime['ResNet34_init'], label = "ResNet34_init")
plt.grid()
plt.legend()
plt.xlabel('epochs')
plt.title("Runtime")
plt.ylim(30, 100)
plt.show()

#----------------


height = [test_accuracy['ResNet34'].item(),test_accuracy['ResNet34_init'].item()]
bars = ('ResNet34','ResNet34_init')
y_pos = np.arange(len(bars))
fig, ax = plt.subplots()
vbars = ax.bar(y_pos, height,color=colors)
ax.bar_label(vbars, fmt='%.2f')
plt.bar(y_pos, height,color=colors)
plt.xticks(y_pos, bars)
plt.title("Test Accuracy (%)")
plt.grid()
plt.ylim(0,100)
plt.show()

#----------------

height = [test_loss['ResNet34'].item(),test_loss['ResNet34_init'].item()]
bars = ('ResNet34','ResNet34_init')
y_pos = np.arange(len(bars))
fig, ax = plt.subplots()
vbars = ax.bar(y_pos, height,color=colors)
ax.bar_label(vbars, fmt='%.2f')
plt.bar(y_pos, height,color=colors)
plt.xticks(y_pos, bars)
plt.title("Test Loss")
plt.grid()
plt.show()
#----------------

# %%
train_loss_ResNet34_init_tensor = torch.tensor(train_loss_ResNet34_init).view(15,-1)
mean_train_loss_ResNet34_init = train_loss_ResNet34_init_tensor.mean(1,True)


linewidth = 1
plt.plot(mean_train_loss_ResNet34, label = "ResNet34",linewidth=linewidth)
plt.plot(mean_train_loss_ResNet34_init, label = "ResNet34 init",linewidth=linewidth)

plt.grid()
plt.ylim(0,0.5)
plt.title("Train loss landscape")
plt.legend()
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# ---------
# # ResNet152 vs ResNet152 init

# %%
plt.plot(val_accuracy['ResNet152'], label = "ResNet152" )
plt.plot(val_accuracy['ResNet152_init'], label = "ResNet152 init" )
plt.title("Validation Accuracy")
plt.xlabel('epochs')
plt.legend()
plt.grid()
plt.ylim(0, 100)
plt.show()

#---------------
plt.plot(val_loss['ResNet152'], label = "ResNet152" )
plt.plot(val_loss['ResNet152_init'], label = "ResNet152 init" )
plt.grid()
plt.legend()
plt.xlabel('epochs')
plt.title("Avarage Validation Loss")
plt.ylim(0, 2)
plt.show()

#---------------

height = [test_accuracy['ResNet152'].item(),test_accuracy['ResNet152_init'].item()]

bars = ('ResNet152','ResNet152 init')
y_pos = np.arange(len(bars))
fig, ax = plt.subplots()
vbars = ax.bar(y_pos, height,color=colors)
ax.bar_label(vbars, fmt='%.2f')
plt.bar(y_pos, height,color=colors)
plt.xticks(y_pos, bars)
plt.title("Test Accuracy (%)")
plt.ylim(0, 100)

plt.grid()
plt.show()
#---------------
height = [test_loss['ResNet152'].item(),test_loss['ResNet152_init'].item()]

bars = ('ResNet152 init','ResNet152 random')
y_pos = np.arange(len(bars))
fig, ax = plt.subplots()
vbars = ax.bar(y_pos, height,color=colors)
ax.bar_label(vbars, fmt='%.2f')
plt.bar(y_pos, height,color=colors)
plt.xticks(y_pos, bars)
plt.title("Test Loss")
plt.ylim(0, 1)
plt.grid()
plt.show()

# %% [markdown]
# ------
